# %% [markdown]
# <a href="https://colab.research.google.com/github/MasrukHabib/Computer_Vision_Practice/blob/main/Background_image_remover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Image Background removing

# %%
# Step 1: Install the rembg library
# !pip install rembg pillow onnxruntime

# Step 2: Upload the image
from google.colab import files
from PIL import Image

print("Please upload an image file.")
uploaded = files.upload()

# Assuming only one file is uploaded
input_file = list(uploaded.keys())[0]

# Step 3: Remove the background
from rembg import remove
import io

# Read the input image
with open(input_file, "rb") as file:
    input_image = file.read()

# Remove background
output_image = remove(input_image)

# Step 4: Save and display the output
output_file = "output_image.png"

# Save the image
with open(output_file, "wb") as file:
    file.write(output_image)

# Display the resulting image
from IPython.display import Image as IPImage, display
print("Here is the image with the background removed:")
display(IPImage(output_file))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 76.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.1 MB/s eta 0:00:00
# ...
# Please upload an image file.
#      <input type="file" id="files-805cdec7-f8c8-4811-95fa-007e3c7746aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-805cdec7-f8c8-4811-95fa-007e3c7746aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# ...
